# %% [markdown]
# <h3 style='text-align:center'>Optimisation Metaheuristiques - Data Generation + Offloading + Pareto</h3>

# %% [markdown]
# ---

# %% [markdown]
# #### LIBRARIES

# %%
import pandas as pd
import random
import sys
sys.path.insert(0, 'utils')


from setPopulations import constructPopulation
from NSGA_II import NSGA_II
from displayFigs import displaySolutions, displayOptimalContent

# %% [markdown]
# #### FUNCTIONS

# %% [markdown]
# #### **Generation Offloading** - Version 1
#
# - TOURNAMENT_SIZE $= 2$
# - CROSSOVER_PROBABILITY $= 0.9$
# - MUTATION_PROBABILITY $= 0.2$
# - N_GENERATIONS $= 20$

# %%
soluce, soluce_T, soluce_Dummy, soluce_Total, soluce_VMS, soluce_IoT = constructPopulation(20)

# %%
display(soluce_T[0].sample(5).reset_index(drop=True))
# Out:
#        TASK        VM        F1           F2
# 0   I20_T01  C01_VM02   4.25563  5784.203787
# 1   I19_T01  C02_VM02  2.987705   3451.89952
# 2   I05_T01  F03_VM02  0.664177     627.9872
# 3  I010_T01  C01_VM02  0.298776   8194.38016
# 4   I17_T01  F01_VM01  4.464164    1708.4824

# %%
TOURNAMENT_SIZE = 2
CROSSOVER_PROBABILITY = 0.9
MUTATION_PROBABILITY = 0.2
N_GENERATIONS = 20
ls_solutions_NSGA2, ls_solutions_dum_NSGA2, df_NSGA2 = NSGA_II(soluce, soluce_Dummy, soluce_Total, soluce_VMS, soluce_IoT, TOURNAMENT_SIZE, CROSSOVER_PROBABILITY, MUTATION_PROBABILITY, N_GENERATIONS)
# Out:
# Current Generation -> 1
# Current Generation -> 2
# Current Generation -> 3
# Current Generation -> 4
# Current Generation -> 5
# Current Generation -> 6
# Current Generation -> 7
# Current Generation -> 8
# Current Generation -> 9
# Current Generation -> 10
# Current Generation -> 11
# Current Generation -> 12
# Current Generation -> 13
# Current Generation -> 14
# Current Generation -> 15
# Current Generation -> 16
# Current Generation -> 17
# Current Generation -> 18
# Current Generation -> 19
# Current Generation -> 20

# %%
display(df_NSGA2)
# Out:
#         Population   ID         F1            F2 RANK  CROWDING_DISTANCE
# 0   Population_406  406  18.684424   47765.41256    1                inf
# 3   Population_206  206  16.285472  52647.047227    1                inf
# 1   Population_332  332  17.263458    49063.6944    1           1.591159
# 2   Population_386  386  16.725424  51546.493627    1           1.141720
# 4   Population_393  393  17.392164   51864.62696    2                inf
# 5   Population_148  148  17.392164   51864.62696    2                inf
# 8   Population_262  262  17.237212  57272.250973    2                inf
# 9   Population_397  397  17.237212  57272.250973    2                inf
# 6   Population_329  329  17.363646  56733.297107    2           1.716291
# 7   Population_413  413  17.363646  56733.297107    2           0.283709
# 10  Population_402  402  17.508664  54811.017907    3                inf
# 11  Population_307  307  19.695875  43253.663493    4                inf
# ...

# %%
displaySolutions(df_NSGA2)

# %%
displayOptimalContent(df_NSGA2, ls_solutions_NSGA2)

# %% [markdown]
# #### **Generation Offloading** - Version 2
#
# - TOURNAMENT_SIZE $= 2$
# - CROSSOVER_PROBABILITY $= 0.9$
# - MUTATION_PROBABILITY $= 0.9$
# - N_GENERATIONS $= 20$

# %%
soluce, soluce_T, soluce_Dummy, soluce_Total, soluce_VMS, soluce_IoT = constructPopulation(20)

# %%
display(soluce_T[0].sample(5).reset_index(drop=True))
# Out:
#        TASK        VM        F1           F2
# 0   I04_T01  F05_VM01  0.568444  2920.745067
# 1   I19_T01  F05_VM04  3.394361    2173.9508
# 2  I010_T01  C02_VM01   1.11325   24236.3584
# 3   I07_T01  F04_VM02  1.476361    2241.8864
# 4   I13_T01  C03_VM01  3.238623  5864.322133

# %%
TOURNAMENT_SIZE = 2
CROSSOVER_PROBABILITY = 0.9
MUTATION_PROBABILITY = 0.9
N_GENERATIONS = 20
ls_solutions_NSGA2, ls_solutions_dum_NSGA2, df_NSGA2 = NSGA_II(soluce, soluce_Dummy, soluce_Total, soluce_VMS, soluce_IoT, TOURNAMENT_SIZE, CROSSOVER_PROBABILITY, MUTATION_PROBABILITY, N_GENERATIONS)
# Out:
# Current Generation -> 1
# Current Generation -> 2
# Current Generation -> 3
# Current Generation -> 4
# Current Generation -> 5
# Current Generation -> 6
# Current Generation -> 7
# Current Generation -> 8
# Current Generation -> 9
# Current Generation -> 10
# Current Generation -> 11
# Current Generation -> 12
# Current Generation -> 13
# Current Generation -> 14
# Current Generation -> 15
# Current Generation -> 16
# Current Generation -> 17
# Current Generation -> 18
# Current Generation -> 19
# Current Generation -> 20

# %%
display(df_NSGA2)
# Out:
#         Population   ID         F1            F2 RANK  CROWDING_DISTANCE
# 0   Population_401  401  27.296963  37199.926133    1                inf
# 2   Population_383  383  19.412992   90070.28384    1                inf
# 1   Population_415  415  21.366001    40608.4652    1           2.000000
# 3   Population_416  416  22.298716    40735.3324    2                inf
# 4   Population_266  266  35.063907  35699.866133    3                inf
# 5   Population_352  352  35.063907  35699.866133    3                inf
# 14  Population_335  335  18.384172   98953.99376    3                inf
# 15  Population_356  356  18.384172   98953.99376    3                inf
# 7   Population_367  367  22.474546    39244.3948    3           0.845904
# 12  Population_369  369  20.259613  80626.635867    3           0.625443
# 11  Population_362  362  20.703388  48176.984187    3           0.517340
# 13  Population_397  397  20.259613  80626.635867    3           0.316347
# ...

# %%
displaySolutions(df_NSGA2)

# %%
displayOptimalContent(df_NSGA2, ls_solutions_NSGA2)

# %% [markdown]
# #### **Generation Offloading** - Version 3
#
# - TOURNAMENT_SIZE $= 5$
# - CROSSOVER_PROBABILITY $= 0.9$
# - MUTATION_PROBABILITY $= 0.2$
# - N_GENERATIONS $= 20$

# %%
soluce, soluce_T, soluce_Dummy, soluce_Total, soluce_VMS, soluce_IoT = constructPopulation(20)

# %%
display(soluce_T[0].sample(5).reset_index(drop=True))
# Out:
#       TASK        VM        F1           F2
# 0  I16_T01  F05_VM03  2.592351     2068.448
# 1  I18_T01  F04_VM01  1.600212      1070.84
# 2  I03_T01  F01_VM02  0.624186      177.098
# 3  I01_T01  F03_VM01   1.13643  1397.772267
# 4  I04_T01  C01_VM02  0.253473  8420.976267

# %%
TOURNAMENT_SIZE = 5
CROSSOVER_PROBABILITY = 0.9
MUTATION_PROBABILITY = 0.2
N_GENERATIONS = 20
ls_solutions_NSGA2, ls_solutions_dum_NSGA2, df_NSGA2 = NSGA_II(soluce, soluce_Dummy, soluce_Total, soluce_VMS, soluce_IoT, TOURNAMENT_SIZE, CROSSOVER_PROBABILITY, MUTATION_PROBABILITY, N_GENERATIONS)
# Out:
# Current Generation -> 1
# Current Generation -> 2
# Current Generation -> 3
# Current Generation -> 4
# Current Generation -> 5
# Current Generation -> 6
# Current Generation -> 7
# Current Generation -> 8
# Current Generation -> 9
# Current Generation -> 10
# Current Generation -> 11
# Current Generation -> 12
# Current Generation -> 13
# Current Generation -> 14
# Current Generation -> 15
# Current Generation -> 16
# Current Generation -> 17
# Current Generation -> 18
# Current Generation -> 19
# Current Generation -> 20

# %%
display(df_NSGA2)
# Out:
#         Population   ID         F1            F2 RANK  CROWDING_DISTANCE
# 0    Population_54   54   16.41035  48032.499893    1                  0
# 1   Population_264  264   16.41035  48032.499893    1                  0
# 2   Population_406  406   16.41035  48032.499893    1                  0
# 3   Population_407  407   16.41035  48032.499893    1                  0
# 4   Population_410  410   16.41035  48032.499893    1                  0
# 5   Population_412  412   16.41035  48032.499893    1                  0
# 6   Population_415  415   16.41035  48032.499893    1                  0
# 7   Population_416  416   16.41035  48032.499893    1                  0
# 8   Population_419  419   16.41035  48032.499893    1                  0
# 9   Population_420  420   16.41035  48032.499893    1                  0
# 10  Population_103  103  16.872138  45070.523493    2                  0
# 11  Population_340  340  16.872138  45070.523493    2                  0
# ...

# %%
displaySolutions(df_NSGA2)

# %%
displayOptimalContent(df_NSGA2, ls_solutions_NSGA2)

# %% [markdown]
# #### **Generation Offloading** - Version 4
#
# - TOURNAMENT_SIZE $= 2$
# - CROSSOVER_PROBABILITY $= 0.9$
# - MUTATION_PROBABILITY $= 0.2$
# - N_GENERATIONS $= 50$

# %%
soluce, soluce_T, soluce_Dummy, soluce_Total, soluce_VMS, soluce_IoT = constructPopulation(20)

# %%
display(soluce_T[0].sample(5).reset_index(drop=True))
# Out:
#        TASK        VM        F1            F2
# 0   I07_T01  F05_VM04  0.664023     3486.2408
# 1   I18_T01  C03_VM01  5.334931  17827.222667
# 2   I09_T01  C02_VM01   1.06563    38786.6472
# 3   I20_T01  C01_VM01  5.791057   5792.136533
# 4  I010_T01  F04_VM01  3.002152     2481.7008

# %%
TOURNAMENT_SIZE = 2
CROSSOVER_PROBABILITY = 0.9
MUTATION_PROBABILITY = 0.2
N_GENERATIONS = 50
ls_solutions_NSGA2, ls_solutions_dum_NSGA2, df_NSGA2 = NSGA_II(soluce, soluce_Dummy, soluce_Total, soluce_VMS, soluce_IoT, TOURNAMENT_SIZE, CROSSOVER_PROBABILITY, MUTATION_PROBABILITY, N_GENERATIONS)
# Out:
# Current Generation -> 1
# Current Generation -> 2
# Current Generation -> 3
# Current Generation -> 4
# Current Generation -> 5
# Current Generation -> 6
# Current Generation -> 7
# Current Generation -> 8
# Current Generation -> 9
# Current Generation -> 10
# Current Generation -> 11
# Current Generation -> 12
# Current Generation -> 13
# Current Generation -> 14
# Current Generation -> 15
# Current Generation -> 16
# Current Generation -> 17
# Current Generation -> 18
# Current Generation -> 19
# Current Generation -> 20
# Current Generation -> 21
# Current Generation -> 22
# Current Generation -> 23
# Current Generation -> 24
# Current Generation -> 25
# Current Generation -> 26
# Current Generation -> 27
# Current Generation -> 28
# Current Generation -> 29
# Current Generation -> 30
# Current Generation -> 31
# Current Generation -> 32
# Current Generation -> 33
# Current Generation -> 34
# Current Generation -> 35
# Current Generation -> 36
# Current Generation -> 37
# ...

# %%
display(df_NSGA2)
# Out:
#          Population    ID         F1            F2 RANK  CROWDING_DISTANCE
# 0    Population_788   788  14.798372   68811.91064    1           0.000000
# 1    Population_990   990  14.798372   68811.91064    1           0.000000
# 2   Population_1012  1012  14.798372   68811.91064    1           0.000000
# 3    Population_674   674  18.984084    50835.9032    2           0.000000
# 4    Population_522   522  18.984084    50835.9032    2           0.000000
# 5   Population_1005  1005  18.984084    50835.9032    2           0.000000
# 6   Population_1011  1011  18.984084    50835.9032    2           0.000000
# 7    Population_781   781  17.522088   65113.71248    3                inf
# 11  Population_1006  1006  17.522088   65113.71248    3                inf
# 17   Population_416   416  11.005018   90258.03576    3                inf
# 21   Population_688   688  11.005018   90258.03576    3                inf
# ...

# %%
displaySolutions(df_NSGA2)
